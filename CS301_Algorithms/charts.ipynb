# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.style.use('default')

# %%
worstcase_sizes = [5,7,10,13,15,18]
dna_sizes = [5,7,9,11,13 ,15,17,19,21]

# %%
naive_worstcase = [0.00019407272338867188, 0.002767801284790039, 0.11921286582946777, 6.7451393604278564, 100.27070736885071, 5889.484976530075]
memoization_worstcase = [2.6226043701171875e-05, 7.462501525878906e-05, 9.608268737792969e-05, 0.00017118453979492188, 0.00020575523376464844, 0.0002942085266113281]

# %%
naive_means = [5.030632019042969e-05, 0.0002816120783487956, 0.002864432334899902, 0.011011004447937012, 0.09361522197723389, 0.6807464122772217, 6.985933248202006, 22.61909037431081, 201.60169631640116]
naive_std =  [3.5001709669360345e-05, 0.0002521321890231313, 0.0027747839943005484, 0.011757820479404803, 0.10554363470140346, 1.3437555965182273, 11.991530573555963, 28.351291677718, 232.17864725939447]
memoization_means =  [1.8223126729329428e-05, 3.2329559326171874e-05, 5.9374173482259114e-05, 8.113384246826172e-05, 0.00010940233866373698, 0.00014275709788004557, 0.000182191530863444, 0.00021981398264567058, 0.0002772410710652669]
memoization_std = [3.8135463912375015e-06, 6.647447479889495e-06, 1.5772607884714944e-05, 1.8387328656836e-05, 2.0876877371507167e-05, 2.6488127690202624e-05, 2.0994294369714344e-05, 4.275625744693555e-05, 5.728403782341773e-05]

# %%
plt.title('Worst-Case Naive Algorithm')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(worstcase_sizes, naive_worstcase, '*-')
plt.xticks(worstcase_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Worst-Case Naive Algorithm (log)')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(worstcase_sizes, naive_worstcase, '*-')
plt.xticks(worstcase_sizes)
plt.yscale("log")
plt.show()

# %%
plt.title('Worst-Case Memoization Algorithm')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(worstcase_sizes, memoization_worstcase, '*-')
plt.xticks(worstcase_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence Naive Means')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, naive_means, '*-')
plt.xticks(dna_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence Naive Standard Deviations')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, naive_std, '*-')
plt.xticks(dna_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence Naive Standard Deviations (Log)')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, naive_std, '*-')
plt.xticks(dna_sizes)
plt.yscale("log")
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence Naive Means (Log)')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, naive_means, '*-')
plt.xticks(dna_sizes)
plt.yscale("log")
plt.show()

# %%
plt.title('Random DNA Sequence Memoization Means')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, memoization_means, '*-')
plt.xticks(dna_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence \nMemoization Standard Deviations')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, memoization_std, '*-')
plt.xticks(dna_sizes)
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()

# %%
plt.title('Random DNA Sequence Means')
plt.xlabel('string length')
plt.ylabel('seconds')
plt.plot(dna_sizes, memoization_means, '*-',label='Memoization')
plt.plot(dna_sizes, naive_means, '*-',label='Naive')
plt.xticks(dna_sizes)
plt.legend()
#plt.plot(labels, memoization_worstcase, '*-')
plt.show()
